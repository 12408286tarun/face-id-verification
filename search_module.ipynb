# %%
import requests
print("requests library working!")
# Out:
# requests library working!

# %%
# !pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if api_key:
    print("Key loaded successfully!")
    print("Key starts with:", api_key[:10])  
else:
    print("Key NOT found - check .env file")
# Out:
# Key NOT found - check .env file

# %%
import requests
import base64

def test_vision_api(image_path):
    with open(image_path, "rb") as img_file:
        image_content = base64.b64encode(img_file.read()).decode("utf-8")

    url = f"https://vision.googleapis.com/v1/images:annotate?key={api_key}"
    
    payload = {
        "requests": [
            {
                "image": {"content": image_content},
                "features": [{"type": "WEB_DETECTION", "maxResults": 10}]
            }
        ]
    }

    response = requests.post(url, json=payload)
    return response.json()

result = test_vision_api("test_image.jpg")
print(result)
# Out:
# {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'vision.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %%
# !pip install google-search-results
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from serpapi import GoogleSearch
from dotenv import load_dotenv
import os

load_dotenv()
serpapi_key = os.getenv("SERPAPI_KEY")

image_url = "https://i.ibb.co/T5pjXhQ/test-image.jpg"

params = {
    "engine": "google_reverse_image",
    "image_url": image_url,
    "api_key": serpapi_key
}

search = GoogleSearch(params)
results = search.get_dict()


print(results)
# Out:
# {'search_metadata': {'id': '6a9b28e3fda6070a57cb2f94', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/HiC1rFkjPDkNBJ3-tZ_vbhR3_xSFLGBVHlDZy87mN88/6a9b28e3fda6070a57cb2f94.json', 'markdown_endpoint': 'https://serpapi.com/searches/HiC1rFkjPDkNBJ3-tZ_vbhR3_xSFLGBVHlDZy87mN88/6a9b28e3fda6070a57cb2f94.md', 'created_at': '2026-09-04 20:24:03 UTC', 'processed_at': '2026-09-04 20:24:03 UTC', 'google_reverse_image_url': 'https://www.google.com/searchbyimage?image_url=https://i.ibb.co/T5pjXhQ/test-image.jpg&sbisrc=cr_1_5_2', 'raw_html_file': 'https://serpapi.com/searches/HiC1rFkjPDkNBJ3-tZ_vbhR3_xSFLGBVHlDZy87mN88/6a9b28e3fda6070a57cb2f94.html', 'total_time_taken': 3.93}, 'search_parameters': {'engine': 'google_reverse_image', 'image_url': 'https://i.ibb.co/T5pjXhQ/test-image.jpg', 'google_domain': 'google.com', 'device': 'desktop'}, 'search_information': {'total_results': 197000, 'time_taken_displayed': 0.56, 'organic_results_state': 'Results for exact spelling'}, 'image_
# ...

# %%
from dotenv import load_dotenv
import os

load_dotenv()
serpapi_key = os.getenv("SERPAPI_KEY")

if serpapi_key:
    print("SerpApi key loaded!")
    print("Length:", len(serpapi_key))
    print("Starts with:", serpapi_key[:5])
else:
    print("SERPAPI_KEY not found in .env")
# Out:
# SerpApi key loaded!
# Length: 64
# Starts with: c4d3d

# %%
def extract_matching_post(results):
    if "image_results" in results and len(results["image_results"]) > 0:
        first_match = results["image_results"][0]
        matched_data = {
            "title": first_match.get("title", "N/A"),
            "url": first_match.get("link", "N/A"),
            "source": first_match.get("source", "N/A"),
            "snippet": first_match.get("snippet", "N/A")
        }
        return matched_data
    else:
        return None

matched_post = extract_matching_post(results)
print(matched_post)
# Out:
# {'title': "Amazon.com: Youths' Classic Navy Blue Blazer, 2-Button ...", 'url': 'https://www.amazon.com/clp/B0FC2B1S7Y', 'source': 'Amazon.com', 'snippet': "Buy Youths' Classic Navy Blue Blazer, 2-Button School Uniform Suit Jacket with Gold Buttons and other Sport Coats & Blazers at Amazon.com."}

# %%
def search_module(image_url):
    """
    Takes an image URL, performs reverse image search via SerpApi,
    returns the best matching post's metadata.
    """
    from serpapi import GoogleSearch
    
    params = {
        "engine": "google_reverse_image",
        "image_url": image_url,
        "api_key": serpapi_key
    }
    
    search = GoogleSearch(params)
    results = search.get_dict()
    
    if "image_results" in results and len(results["image_results"]) > 0:
        first_match = results["image_results"][0]
        return {
            "title": first_match.get("title", "N/A"),
            "url": first_match.get("link", "N/A"),
            "source": first_match.get("source", "N/A"),
            "snippet": first_match.get("snippet", "N/A")
        }
    else:
        return None

test_result = search_module("https://i.ibb.co/T5pjXhQ/test-image.jpg")
print(test_result)
# Out:
# {'title': "Amazon.com: Youths' Classic Navy Blue Blazer, 2-Button ...", 'url': 'https://www.amazon.com/clp/B0FC2B1S7Y', 'source': 'Amazon.com', 'snippet': "Buy Youths' Classic Navy Blue Blazer, 2-Button School Uniform Suit Jacket with Gold Buttons and other Sport Coats & Blazers at Amazon.com."}
